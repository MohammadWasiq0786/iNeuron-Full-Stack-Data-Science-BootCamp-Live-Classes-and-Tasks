# %% [markdown]
# # Time Series Analysis Using Python
#
# ## Day - I

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df_tesla= pdr.get_data_yahoo("TSLA")
df_tesla
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-10-02   22.913334   22.367332   22.834667   22.768667   79302000.0
# 2017-10-03   23.236668   22.085333   22.393333   23.209333  152304000.0
# 2017-10-04   23.908001   23.306667   23.416668   23.667334  122452500.0
# 2017-10-05   23.829332   23.423332   23.733334   23.688667   62575500.0
# 2017-10-06   24.006666   23.483334   23.540001   23.792000   64462500.0
# ...                ...         ...         ...         ...          ...
# 2022-09-26  284.089996  270.309998  271.829987  276.010010   58076900.0
# 2022-09-27  288.670013  277.510010  283.839996  282.940002   61925200.0
# 2022-09-28  289.000000  277.570007  283.079987  287.809998   54664800.0
# 2022-09-29  283.649994  265.779999  282.760010  268.209991   77620600.0
# 2022-09-30  275.570007  262.470001  266.149994  265.250000   67517800.0
#
#              Adj Close
# Date
# 2017-10-02   22.768667
# 2017-10-03   23.209333
# ...

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2017-10-02 to 2022-09-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1259 non-null   float64
#  1   Low        1259 non-null   float64
#  2   Open       1259 non-null   float64
#  3   Close      1259 non-null   float64
#  4   Volume     1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
# dtypes: float64(6)
# memory usage: 68.9 KB

# %%
df_tesla.isnull().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
df_tesla.describe().T
# Out:
#             count          mean           std           min           25%  \
# High       1259.0  1.262806e+02  1.220132e+02  1.244533e+01  2.112733e+01
# Low        1259.0  1.203632e+02  1.162426e+02  1.179933e+01  2.035067e+01
# Open       1259.0  1.234370e+02  1.192958e+02  1.207333e+01  2.081167e+01
# Close      1259.0  1.233987e+02  1.191482e+02  1.193133e+01  2.078167e+01
# Volume     1259.0  1.317663e+08  9.038528e+07  2.940180e+07  7.470510e+07
# Adj Close  1259.0  1.233987e+02  1.191482e+02  1.193133e+01  2.078167e+01
#
#                     50%           75%           max
# High       5.166333e+01  2.395650e+02  4.144967e+02
# Low        4.774067e+01  2.297133e+02  4.056667e+02
# Open       4.945600e+01  2.349617e+02  4.114700e+02
# Close      4.993067e+01  2.356717e+02  4.099700e+02
# Volume     1.014435e+08  1.526895e+08  9.140820e+08
# Adj Close  4.993067e+01  2.356717e+02  4.099700e+02

# %%
df_tesla.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# x-limit and y-limit
df_tesla['High'].plot(xlim= ['2020-01-01', '2021-09-01'], figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].plot(xlim= ['2022-01-01', '2021-09-30'], figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].plot(xlim= ['2020-01-01', '2021-09-01'], ylim= [0, 900], figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].plot(xlim= ['2020-01-01', '2021-09-01'], figsize=(12,4), ls='--', c='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].plot(xlim= ['2020-01-01', '2021-09-01'], figsize=(12,4), ls='dotted', c='green')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2017-10-02', '2017-10-03', '2017-10-04', '2017-10-05',
#                '2017-10-06', '2017-10-09', '2017-10-10', '2017-10-11',
#                '2017-10-12', '2017-10-13',
#                ...
#                '2022-09-19', '2022-09-20', '2022-09-21', '2022-09-22',
#                '2022-09-23', '2022-09-26', '2022-09-27', '2022-09-28',
#                '2022-09-29', '2022-09-30'],
#               dtype='datetime64[ns]', name='Date', length=1259, freq=None)

# %%
index= df_tesla.loc['2020-01-01' : '2021-09-01'].index

share_open= df_tesla.loc['2020-01-01' : '2021-09-01']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     28.299999
# 2020-01-03     29.366667
# 2020-01-06     29.364668
# 2020-01-07     30.760000
# 2020-01-08     31.580000
#                  ...
# 2021-08-26    236.103333
# 2021-08-27    235.000000
# 2021-08-30    238.240005
# 2021-08-31    244.333328
# 2021-09-01    244.693329
# Name: Open, Length: 421, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure, axis= plt.subplots()
axis.plot(index, share_open)

# %%
figure, axis= plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
axis.plot(index, share_open)

# %%
df_tesla= df_tesla.reset_index()

# %%
df_tesla.head()
# Out:
#         Date       High        Low       Open      Close       Volume  \
# 0 2017-10-02  22.913334  22.367332  22.834667  22.768667   79302000.0
# 1 2017-10-03  23.236668  22.085333  22.393333  23.209333  152304000.0
# 2 2017-10-04  23.908001  23.306667  23.416668  23.667334  122452500.0
# 3 2017-10-05  23.829332  23.423332  23.733334  23.688667   62575500.0
# 4 2017-10-06  24.006666  23.483334  23.540001  23.792000   64462500.0
#
#    Adj Close
# 0  22.768667
# 1  23.209333
# 2  23.667334
# 3  23.688667
# 4  23.792000

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   High       1259 non-null   float64
#  2   Low        1259 non-null   float64
#  3   Open       1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Volume     1259 non-null   float64
#  6   Adj Close  1259 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 69.0 KB

# %%
df_tesla= df_tesla.set_index('Date', drop=True)
df_tesla.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2017-10-02  22.913334  22.367332  22.834667  22.768667   79302000.0  22.768667
# 2017-10-03  23.236668  22.085333  22.393333  23.209333  152304000.0  23.209333
# 2017-10-04  23.908001  23.306667  23.416668  23.667334  122452500.0  23.667334
# 2017-10-05  23.829332  23.423332  23.733334  23.688667   62575500.0  23.688667
# 2017-10-06  24.006666  23.483334  23.540001  23.792000   64462500.0  23.792000

# %%
from datetime import datetime
datetime(2021, 10, 2)
# Out:
# datetime.datetime(2021, 10, 2, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 10, 2, 17, 14, 36, 391002)

# %%
def add_number(num1, num2):
    return num1+num2

# %%
start_time= datetime.now()
num1= 20
num2= 30

for i in [1,2,3,4,5]:
    add_number(num1, num2)

end_time= datetime.now()

print(end_time- start_time)
# Out:
# 0:00:00

# %%
df_tesla.resample(rule='A').max()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-12-31   24.200001   23.608667   23.798668   23.976667  296871000.0
# 2018-12-31   25.830667   24.474667   25.000000   25.304667  504745500.0
# 2019-12-31   29.020666   28.423332   29.000000   28.729334  450091500.0
# 2020-12-31  239.573334  230.373337  233.330002  235.223328  914082000.0
# 2021-12-31  414.496674  405.666656  411.470001  409.970001  268189500.0
# 2022-12-31  402.666656  378.679993  396.516663  399.926666  151565700.0
#
#              Adj Close
# Date
# 2017-12-31   23.976667
# 2018-12-31   25.304667
# 2019-12-31   28.729334
# 2020-12-31  235.223328
# 2021-12-31  409.970001
# 2022-12-31  399.926666

# %%
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='A').mean().plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='M').max().plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['High'].rolling(10).mean()
# Out:
# Date
# 2017-10-02           NaN
# 2017-10-03           NaN
# 2017-10-04           NaN
# 2017-10-05           NaN
# 2017-10-06           NaN
#                  ...
# 2022-09-26    302.307996
# 2022-09-27    301.434998
# 2022-09-28    299.734998
# 2022-09-29    297.187997
# 2022-09-30    294.373999
# Name: High, Length: 1259, dtype: float64

# %%
df_tesla.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2017-10-02  22.913334  22.367332  22.834667  22.768667   79302000.0  22.768667
# 2017-10-03  23.236668  22.085333  22.393333  23.209333  152304000.0  23.209333
# 2017-10-04  23.908001  23.306667  23.416668  23.667334  122452500.0  23.667334
# 2017-10-05  23.829332  23.423332  23.733334  23.688667   62575500.0  23.688667
# 2017-10-06  24.006666  23.483334  23.540001  23.792000   64462500.0  23.792000

# %% [markdown]
# ## Day - II

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import pandas_datareader as pdr

# %%
df_tesla= pdr.get_data_yahoo('TSLA')
df_tesla
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-10-02   22.913334   22.367332   22.834667   22.768667   79302000.0
# 2017-10-03   23.236668   22.085333   22.393333   23.209333  152304000.0
# 2017-10-04   23.908001   23.306667   23.416668   23.667334  122452500.0
# 2017-10-05   23.829332   23.423332   23.733334   23.688667   62575500.0
# 2017-10-06   24.006666   23.483334   23.540001   23.792000   64462500.0
# ...                ...         ...         ...         ...          ...
# 2022-09-26  284.089996  270.309998  271.829987  276.010010   58076900.0
# 2022-09-27  288.670013  277.510010  283.839996  282.940002   61925200.0
# 2022-09-28  289.000000  277.570007  283.079987  287.809998   54664800.0
# 2022-09-29  283.649994  265.779999  282.760010  268.209991   77620600.0
# 2022-09-30  275.570007  262.470001  266.149994  265.250000   67517800.0
#
#              Adj Close
# Date
# 2017-10-02   22.768667
# 2017-10-03   23.209333
# ...

# %% [markdown]
# **Simple Moving Average**

# %%
df_tesla['Open'].plot(figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open:10 days rolling']= df_tesla['Open'].rolling(window=10, min_periods=1).mean()

# %%
df_tesla[['Open', 'Open:10 days rolling']].plot(figsize= (15, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla[['Open', 'Open:10 days rolling']].plot(xlim=['2020-01-01', '2021-01-01'], figsize= (15, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open:30 days rolling']= df_tesla['Open'].rolling(window=30, min_periods=1).mean()

df_tesla['Open:50 days rolling']= df_tesla['Open'].rolling(window=50, min_periods=1).mean()

# %%
df_tesla[['Open', 'Open:10 days rolling', 'Open:30 days rolling', 'Open:50 days rolling']].plot(xlim=['2020-01-01', '2021-01-01'], figsize= (15, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# **CMA**

# %%
df_tesla['Open'].expanding().mean().plot(figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# **EMA TESLA Share**
#
# Let's smooting factor= 0.1

# %%
df_tesla['EMA_5days']= df_tesla['Open'].ewm(span=5).mean()

# %%
df_tesla[['Open', 'EMA_5days']].plot(figsize= (10, 5))
# Out:
# <AxesSubplot:xlabel='Date'>
