# %% [markdown]
#
#
#   <img height=60 align="center" src="data:image/png;base64,..." alt="Red dot" />

# %% [markdown]
# # Name : Mohammad Wasiq
# ## University : Aligarh Muslim University
# ## Department : Department of Statistics & Operation Research , AMU , Aligarh (202002)
# ## Education : B.Sc (Statistics)[2018-2021], M.Sc(Data Science)[2021-2023]
# ## Contact No. : +91-9927373137
# ## E-mail : gl0427@myamu.ac.in , mohammadwasiq0786@gmail.com
# ## LinkedIn : https://www.linkedin.com/in/mohammad-wasiq-198327217
# ## Twitter : https://mobile.twitter.com/Mohammadwasiq0
# ## Github : https://github.com/MohammadWasiq0786?tab=repositories
# ## Kaggle :https://www.kaggle.com/mohammadwasiqqcs
# ## Instagram: https://www.instagram.com/mohammadwasiq0786/
# ## Facebook : https://www.facebook.com/mohammad.wasiq.79
#
# # iNeuron Full Stack Data Science Bootcamp
# I **Mohamamd Wasiq** enroled in `Full Stack Data Science Bootcamp` at **iNeuron**.
# <br> This couse is start at **7-May-20022**
# <br> Day one **7-May-20022** and Day two **8-May-20022** are introductry classes.
#
# ## Mentors
#
# ### Sudhanshu Kumar  Sir
# #### E-mail -: sudhanshu@ineuron.ai  , Mobile No. -: +91-9176072251
#
# ### Krish Naik Sir
# #### E-mail -: krishnaik@ineuron.ai  , Mobile No. -: +91-9899399757
#
# ### Sunny Sir
# #### E-mail -: sunny.savita@ineuron.ai  , Mobile No. -:
#
# ### Shivan Sir
# #### E-mail -: shivan@ineuron.ai  , Mobile No. -: +91-6280963446
#
#
#
#
# # Introduction to Python
#
# # Class - 3 `Introduction of Variables`
#
# ## 14-May-2022

# %%
1+1
# Out:
# 2

# %% [markdown]
# Not able to do modular coding for project in Jupyter Notebook. Then we will use pycharm or Visual Studio
# Jupyter notebook does not execute Python Code. Python compiler does that.

# %%
wasiq = 100
wasiq
# Out:
# 100

# %%
wasiq - 2
# Out:
# 98

# %%
type(wasiq)
# Out:
# int

# %%
a = 34.09
a
# Out:
# 34.09

# %%
type(a)
# Out:
# float

# %%
b = 'This is my first class of python and todays date is 14th May 2022'
b
# Out:
# 'This is my first class of python and todays date is 14th May 2022'

# %%
type(b)
# Out:
# str

# %%
True - False # 1-0 = 1
# Out:
# 1

# %%
e = False
type(e)
# Out:
# bool

# %%
True - True
# Out:
# 0

# %%
True / False # 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# e:\I Wasiq\By Others\iNeuron-Live-Classes-Tasks-main\Class 3_FSDS_Variable Intro.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/I%20Wasiq/By%20Others/iNeuron-Live-Classes-Tasks-main/Class%203_FSDS_Variable%20Intro.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> True / False
#
# ZeroDivisionError: division by zero

# %% [markdown]
# In Numpy module if we do 1/0, we get inf and not 0 division error

# %%
n = 5 + 7j # Complex

# %%
type(n)
# Out:
# complex

# %%
n + n
# Out:
# (10+14j)

# %%
n.real, n.imag
# Out:
# (5.0, 7.0)

# %%
type()  # Go inside the function and press Shift + Tab to get hint what function does
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\I Wasiq\By Others\iNeuron-Live-Classes-Tasks-main\Class 3_FSDS_Variable Intro.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/I%20Wasiq/By%20Others/iNeuron-Live-Classes-Tasks-main/Class%203_FSDS_Variable%20Intro.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
l = [1, 2, 3, 4, 'Wasiq', 243.36, 5+9j]
l
# Out:
# [1, 2, 3, 4, 'Wasiq', 243.36, (5+9j)]

# %%
type(l)
# Out:
# list

# %%
l[0], l[5] # Extract the elements located at 0th  and 5th position
# Out:
# (1, 243.36)

# %%
t = (1, 2, 3, 4, 'Wasiq', 243.36, 5+9j)
t
# Out:
# (1, 2, 3, 4, 'Wasiq', 243.36, (5+9j))

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# The key difference between the `tuples` and `lists` is that while the `tuples` are **immutable** objects the `lists` are **mutable**.
#
# This means that tuples cannot be changed while the lists can be modified.

# %%
d = {'a':'Wasiq','b':24}
d
# Out:
# {'a': 'Wasiq', 'b': 24}

# %%
type(d)
# Out:
# dict

# %%
e = {2231, 231, "xyz"}
e
# Out:
# {2231, 231, 'xyz'}

# %%
type(e)
# Out:
# set

# %% [markdown]
# # Class - 4 String
#
# ## 15-May-2022

# %%
s = 'ineuron'
s
# Out:
# 'ineuron'

# %%
type(s)
# Out:
# str

# %% [markdown]
# In `Python` indexing starts from **0** while in `R` indexing starts from **1**

# %%
s[0:2] #2 index is not extracted
# Out:
# 'in'

# %%
s[0:4]
# Out:
# 'ineu'

# %%
s[-1]
# Out:
# 'n'

# %%
s[-2]
# Out:
# 'o'

# %%
g = 'wasiq'

# %%
g
# Out:
# 'wasiq'

# %%
m = "My name is Mohammad Wasiq"
m
# Out:
# 'My name is Mohammad Wasiq'

# %%
m[1:5]
# Out:
# 'y na'

# %%
m[1:5: 2] # Last 2 means jump of 2
# Out:
# 'yn'

# %%
m[1:12: 2]
# Out:
# 'ynm sM'

# %%
s = 'sudhanshu'
s[0:8:-1]   # Contradiction hence blank
# Out:
# ''

# %%
# No Contradiction, hence we are getting output
s[8:0: -1]
# Out:
# 'uhsnahdu'

# %%
s[:3]
# Out:
# 'sud'

# %%
s[:-3]
# Out:
# 'sudhan'

# %%
s[-2:]
# Out:
# 'hu'

# %%
# Entire string will be returned as only jump/step-size is given
s[::1]
# Out:
# 'sudhanshu'

# %%
s[0:50: 1]
# Out:
# 'sudhanshu'

# %%
s[::-1]  # Reverse of the string
# Out:
# 'uhsnahdus'

# %%
s[8:0: -1]
# Out:
# 'uhsnahdu'

# %%
s[-2:-7: 1] # Contradiction
# Out:
# ''

# %%
s[-7:-2: 1]
# Out:
# 'dhans'

# %%
# Contradiction because by default jump is towards right side 
s[5:0]
# Out:
# ''

# %%
s[:-1:-1] # Contradiction
# Out:
# ''

# %%
s + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 s + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s + '1'
# Out:
# 'sudhanshu1'

# %%
len(s)
# Out:
# 9

# %%
s*4
# Out:
# 'sudhanshusudhanshusudhanshusudhanshu'

# %%
s.count('s')
# Out:
# 2

# %%
s.count('su')
# Out:
# 1

# %%
s.split('u')
# Out:
# ['s', 'dhansh', '']

# %%
sw = "The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea."
sw
# Out:
# 'The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.'

# %%
sw.split(' ')
# Out:
# ['The',
#  'Samsung',
#  'Group[3]',
#  '(or',
#  'simply',
#  'Samsung,',
#  'stylized',
#  'as',
#  'SΛMSUNG)',
#  '(Korean:',
#  '삼성',
#  '[samsʌŋ])',
#  'is',
#  'a',
#  'South',
#  'Korean',
#  'multinational',
#  'manufacturing',
#  'conglomerate',
#  'headquartered',
#  'in',
#  'Samsung',
#  'Town,',
#  'Seoul,',
#  'South',
#  'Korea.']

# %%
sw2 = "The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1] It comprises numerous affiliated businesses,[1] most of them united under the Samsung brand, and is the largest South Korean chaebol (business conglomerate). As of 2020, Samsung has the 8th highest global brand value.[4]

Samsung was founded by Lee Byung-chul in 1938 as a trading company. Over the next three decades, the group diversified into areas including food processing, textiles, insurance, securities, and retail. Samsung entered the electronics industry in the late 1960s and the construction and shipbuilding industries in the mid-1970s; these areas would drive its subsequent growth. Following Lee's death in 1987, Samsung was separated into five business groups – Samsung Group, Shinsegae Group, CJ Group and Hansol Group, and Joongang Group.

Notable Samsung industrial affiliates include Samsung Electronics (the world's largest information technology company, consumer electronics maker and chipmaker measured by 2017 revenues),[5][6] Samsung Heavy Industries (the world's 2nd largest shipbuilder measured by 2010 revenues),[7] and Samsung Engineering and Samsung C&T Corporation (respectively the world's 13th and 36th largest construction companies).[8] Other notable subsidiaries include Samsung Life Insurance (the world's 14th largest life insurance company),[9] Samsung Everland (operator of Everland Resort, the oldest theme park in South Korea)[10] and Cheil Worldwide (the world's 15th largest advertising agency, as measured by 2012 revenues)."
# Out:
#   Input In [37]
#     sw2 = "The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1] It comprises numerous affiliated businesses,[1] most of them united under the Samsung brand, and is the largest South Korean chaebol (business conglomerate). As of 2020, Samsung has the 8th highest global brand value.[4]
#                                                                                                                                                                                                                                                                                                                                                                                                                                             ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# When we have multi line string then we need to encose with triple quotes $"""\,\,\,"""$

# %%
sw2 = '''The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1] It comprises numerous affiliated businesses,[1] most of them united under the Samsung brand, and is the largest South Korean chaebol (business conglomerate). As of 2020, Samsung has the 8th highest global brand value.[4]

Samsung was founded by Lee Byung-chul in 1938 as a trading company. Over the next three decades, the group diversified into areas including food processing, textiles, insurance, securities, and retail. Samsung entered the electronics industry in the late 1960s and the construction and shipbuilding industries in the mid-1970s; these areas would drive its subsequent growth. Following Lee's death in 1987, Samsung was separated into five business groups – Samsung Group, Shinsegae Group, CJ Group and Hansol Group, and Joongang Group.

Notable Samsung industrial affiliates include Samsung Electronics (the world's largest information technology company, consumer electronics maker and chipmaker measured by 2017 revenues),[5][6] Samsung Heavy Industries (the world's 2nd largest shipbuilder measured by 2010 revenues),[7] and Samsung Engineering and Samsung C&T Corporation (respectively the world's 13th and 36th largest construction companies).[8] Other notable subsidiaries include Samsung Life Insurance (the world's 14th largest life insurance company),[9] Samsung Everland (operator of Everland Resort, the oldest theme park in South Korea)[10] and Cheil Worldwide (the world's 15th largest advertising agency, as measured by 2012 revenues).'''

sw2
# Out:
# "The Samsung Group[3] (or simply Samsung, stylized as SΛMSUNG) (Korean: 삼성 [samsʌŋ]) is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1] It comprises numerous affiliated businesses,[1] most of them united under the Samsung brand, and is the largest South Korean chaebol (business conglomerate). As of 2020, Samsung has the 8th highest global brand value.[4]\n\nSamsung was founded by Lee Byung-chul in 1938 as a trading company. Over the next three decades, the group diversified into areas including food processing, textiles, insurance, securities, and retail. Samsung entered the electronics industry in the late 1960s and the construction and shipbuilding industries in the mid-1970s; these areas would drive its subsequent growth. Following Lee's death in 1987, Samsung was separated into five business groups – Samsung Group, Shinsegae Group, CJ Group and Hansol Group, and Joongang Group.\n\nNotable Samsung industrial affiliates 
# ...

# %%
sw2.split(' ')
# Out:
# ['The',
#  'Samsung',
#  'Group[3]',
#  '(or',
#  'simply',
#  'Samsung,',
#  'stylized',
#  'as',
#  'SΛMSUNG)',
#  '(Korean:',
#  '삼성',
#  '[samsʌŋ])',
#  'is',
#  'a',
#  'South',
#  'Korean',
#  'multinational',
#  'manufacturing',
#  'conglomerate',
#  'headquartered',
#  'in',
#  'Samsung',
#  'Town,',
#  'Seoul,',
#  'South',
#  'Korea.[1]',
#  'It',
#  'comprises',
#  'numerous',
#  'affiliated',
#  'businesses,[1]',
#  'most',
#  'of',
#  'them',
#  'united',
#  'under',
#  'the',
#  'Samsung',
#  'brand,',
#  'and',
#  'is',
#  'the',
#  'largest',
#  'South',
#  'Korean',
#  'chaebol',
#  '(business',
#  'conglomerate).',
#  'As',
#  'of',
#  '2020,',
#  'Samsung',
#  'has',
#  'the',
#  '8th',
#  'highest',
#  'global',
#  'brand',
#  'value.[4]\n\nSamsung',
#  'was',
#  'founded',
#  'by',
#  'Lee',
#  'Byung-chul',
#  'in',
#  '1938',
#  'as',
#  'a',
#  'trading',
#  'company.',
#  'Over',
#  'the',
#  'next',
#  'three',
#  'decades,',
#  'the',
#  'group',
# ...

# %%
sw2.upper()
# Out:
# "THE SAMSUNG GROUP[3] (OR SIMPLY SAMSUNG, STYLIZED AS SΛMSUNG) (KOREAN: 삼성 [SAMSɅŊ]) IS A SOUTH KOREAN MULTINATIONAL MANUFACTURING CONGLOMERATE HEADQUARTERED IN SAMSUNG TOWN, SEOUL, SOUTH KOREA.[1] IT COMPRISES NUMEROUS AFFILIATED BUSINESSES,[1] MOST OF THEM UNITED UNDER THE SAMSUNG BRAND, AND IS THE LARGEST SOUTH KOREAN CHAEBOL (BUSINESS CONGLOMERATE). AS OF 2020, SAMSUNG HAS THE 8TH HIGHEST GLOBAL BRAND VALUE.[4]\n\nSAMSUNG WAS FOUNDED BY LEE BYUNG-CHUL IN 1938 AS A TRADING COMPANY. OVER THE NEXT THREE DECADES, THE GROUP DIVERSIFIED INTO AREAS INCLUDING FOOD PROCESSING, TEXTILES, INSURANCE, SECURITIES, AND RETAIL. SAMSUNG ENTERED THE ELECTRONICS INDUSTRY IN THE LATE 1960S AND THE CONSTRUCTION AND SHIPBUILDING INDUSTRIES IN THE MID-1970S; THESE AREAS WOULD DRIVE ITS SUBSEQUENT GROWTH. FOLLOWING LEE'S DEATH IN 1987, SAMSUNG WAS SEPARATED INTO FIVE BUSINESS GROUPS – SAMSUNG GROUP, SHINSEGAE GROUP, CJ GROUP AND HANSOL GROUP, AND JOONGANG GROUP.\n\nNOTABLE SAMSUNG INDUSTRIAL AFFILIATES 
# ...

# %%
sw2.lower()
# Out:
# "the samsung group[3] (or simply samsung, stylized as sλmsung) (korean: 삼성 [samsʌŋ]) is a south korean multinational manufacturing conglomerate headquartered in samsung town, seoul, south korea.[1] it comprises numerous affiliated businesses,[1] most of them united under the samsung brand, and is the largest south korean chaebol (business conglomerate). as of 2020, samsung has the 8th highest global brand value.[4]\n\nsamsung was founded by lee byung-chul in 1938 as a trading company. over the next three decades, the group diversified into areas including food processing, textiles, insurance, securities, and retail. samsung entered the electronics industry in the late 1960s and the construction and shipbuilding industries in the mid-1970s; these areas would drive its subsequent growth. following lee's death in 1987, samsung was separated into five business groups – samsung group, shinsegae group, cj group and hansol group, and joongang group.\n\nnotable samsung industrial affiliates 
# ...

# %%
sw2.capitalize()
# Out:
# "The samsung group[3] (or simply samsung, stylized as sλmsung) (korean: 삼성 [samsʌŋ]) is a south korean multinational manufacturing conglomerate headquartered in samsung town, seoul, south korea.[1] it comprises numerous affiliated businesses,[1] most of them united under the samsung brand, and is the largest south korean chaebol (business conglomerate). as of 2020, samsung has the 8th highest global brand value.[4]\n\nsamsung was founded by lee byung-chul in 1938 as a trading company. over the next three decades, the group diversified into areas including food processing, textiles, insurance, securities, and retail. samsung entered the electronics industry in the late 1960s and the construction and shipbuilding industries in the mid-1970s; these areas would drive its subsequent growth. following lee's death in 1987, samsung was separated into five business groups – samsung group, shinsegae group, cj group and hansol group, and joongang group.\n\nnotable samsung industrial affiliates 
# ...

# %%
sw2 = sw2.upper()

# %%
sw2
# Out:
# "THE SAMSUNG GROUP[3] (OR SIMPLY SAMSUNG, STYLIZED AS SΛMSUNG) (KOREAN: 삼성 [SAMSɅŊ]) IS A SOUTH KOREAN MULTINATIONAL MANUFACTURING CONGLOMERATE HEADQUARTERED IN SAMSUNG TOWN, SEOUL, SOUTH KOREA.[1] IT COMPRISES NUMEROUS AFFILIATED BUSINESSES,[1] MOST OF THEM UNITED UNDER THE SAMSUNG BRAND, AND IS THE LARGEST SOUTH KOREAN CHAEBOL (BUSINESS CONGLOMERATE). AS OF 2020, SAMSUNG HAS THE 8TH HIGHEST GLOBAL BRAND VALUE.[4]\n\nSAMSUNG WAS FOUNDED BY LEE BYUNG-CHUL IN 1938 AS A TRADING COMPANY. OVER THE NEXT THREE DECADES, THE GROUP DIVERSIFIED INTO AREAS INCLUDING FOOD PROCESSING, TEXTILES, INSURANCE, SECURITIES, AND RETAIL. SAMSUNG ENTERED THE ELECTRONICS INDUSTRY IN THE LATE 1960S AND THE CONSTRUCTION AND SHIPBUILDING INDUSTRIES IN THE MID-1970S; THESE AREAS WOULD DRIVE ITS SUBSEQUENT GROWTH. FOLLOWING LEE'S DEATH IN 1987, SAMSUNG WAS SEPARATED INTO FIVE BUSINESS GROUPS – SAMSUNG GROUP, SHINSEGAE GROUP, CJ GROUP AND HANSOL GROUP, AND JOONGANG GROUP.\n\nNOTABLE SAMSUNG INDUSTRIAL AFFILIATES 
# ...

# %%
s = 'mohammad wasiq qcs'  
s.title()
# Out:
# 'Mohammad Wasiq Qcs'

# %%
# First Character Upper case and other as lower case
s.capitalize()
# Out:
# 'Mohammad wasiq qcs'

# %%
s.swapcase()
# Out:
# 'MOHAMMAD WASIQ QCS'

# %%
# Returns an object (We have performed Join operation on blank)
''.join(reversed(s))
# Out:
# 'scq qisaw dammahom'

# %%
s[::-1]
# Out:
# 'scq qisaw dammahom'

# %%
t = "    ds   dsa  d sadas "  #Leading and Trailing space only stripped
t.strip()
# Out:
# 'ds   dsa  d sadas'

# %%
t.lstrip()
# Out:
# 'ds   dsa  d sadas '

# %%
t.rstrip()
# Out:
# '    ds   dsa  d sadas'

# %%
" ".join("sudhanshu")
# Out:
# 's u d h a n s h u'

# %%
"a".join("sudhanshu")
# Out:
# 'sauadahaaanasahau'

# %%
s = 'sudh'
s.center(20,'z')
s.center()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 3>()
#       1 s = 'sudh'
#       2 s.center(20,'z')
# ----> 3 s.center()
#
# TypeError: center expected at least 1 argument, got 0

# %%
s = "sudhanshu"
s.isupper()
# Out:
# False

# %%
s.islower()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s = 'Mohammad Wasiq'
s.isspace()
# Out:
# False

# %%
s4 = ' '
s4.isspace()
# Out:
# True

# %%
s.isdigit()
# Out:
# False

# %%
s6 = 'sf4565'
s6.isdigit()
# Out:
# False

# %%
s7 = '12345'
s7.isdigit()
# Out:
# True

# %%
s6.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# False

# %%
s.startswith('S')
# Out:
# False

# %%
s.startswith('s')
# Out:
# False

# %%
s.startswith('M')
# Out:
# True

# %%
s.endswith('q')
# Out:
# True

# %%
s.isascii()
# Out:
# True

# %%
p1 = '2343343'
p1.isdigit()
# Out:
# True

# %%
p2 = '3232 435353'
p2.isdigit()
# Out:
# False

# %%
p2.isnumeric() # Same answer
# Out:
# False

# %%
s = 'Mohammad\tWasiq\tQCS'
s
# Out:
# 'Mohammad\tWasiq\tQCS'

# %%
s.expandtabs()
# Out:
# 'Mohammad        Wasiq   QCS'

# %% [markdown]
# # Task - 1
# **sudhanshu@ineuron.ai, sunny.savita@ineuron.ai, shivan@ineuron.ai**
#
# **s = "this is My First Python programming class and i am learNING python string and its function"**
# 1. Try to extract data from index one to index 300 with a jump 0f 3
# 2. Try to reverse a string without using reverse function
# 3. Try to split a string after conversion of entire string in uppercase
# 4. Try to convert whole string into lower case
# 5. Try to capitalize whole string
# 6. Write difference between `isalnum()` and `isalpha()`
# 7. Try to give an example of exapand tab
# 8. Give an example of strip, lstrip and rstrip
# 9. Replace a string character by another character by taking your own example
# 10. Try to give a definition of string center function with an example
# 11. Write your definition of compiler and interpretor without copy paste from internet
# 12. Python is an interpreted or compile language. Give a clear answer  with your understanding
# 13. Try to write a use case of python with your understanding
#
# ## Solution of Task - 1
# **s = "this is My First Python programming class and i am learNING python string and its function"**
# 1. Try to extract data from index one to index 300 with a jump 0f 3

# %%
s = "this is My First Python programming class and i am learNING python string and its function"
s[1:300: 3]
# Out:
# 'h   r tnrrmglsnimeNGyosi dtfco'

# %% [markdown]
# 2. Try to reverse a string without using reverse function

# %%
s[::-1]
# Out:
# 'noitcnuf sti dna gnirts nohtyp GNINrael ma i dna ssalc gnimmargorp nohtyP tsriF yM si siht'

# %% [markdown]
# 3. Try to split a string after conversion of entire string in uppercase

# %%
S1 = s.upper() 
S1.split(' ')
# Out:
# ['THIS',
#  'IS',
#  'MY',
#  'FIRST',
#  'PYTHON',
#  'PROGRAMMING',
#  'CLASS',
#  'AND',
#  'I',
#  'AM',
#  'LEARNING',
#  'PYTHON',
#  'STRING',
#  'AND',
#  'ITS',
#  'FUNCTION']

# %% [markdown]
# 4. Try to convert whole string into lower case

# %%
s.lower()
# Out:
# 'this is my first python programming class and i am learning python string and its function'

# %% [markdown]
# 5. Try to capitalize whole string

# %%
s.capitalize()
# Out:
# 'This is my first python programming class and i am learning python string and its function'

# %% [markdown]
# 6. Write difference between `isalnum()` and `isalpha()`
#
# The Python `isalpha()` method returns true if a string only contains letters where as Python `isalnum()` only returns true if a string contains alphanumeric characters, without symbols.

# %%
s2 = 'dsadw323'
s2.isalnum()
# Out:
# True

# %%
s1 = 'asdsasa'
s1.isalpha()
# Out:
# True

# %% [markdown]
# 7. Try to give an example of exapand tab

# %%
g = 'Mohammad\tWasiq\tQCS'
g.expandtabs()
# Out:
# 'Mohammad        Wasiq   QCS'

# %% [markdown]
# 8. Give an example of `strip`, `lstrip` and `rstrip`

# %%
t = "    ds   dsa  d sadas "  # Leading and Trailing space only stripped
t.strip()
# Out:
# 'ds   dsa  d sadas'

# %%
t.lstrip()  # Only leading Spaces stripped
# Out:
# 'ds   dsa  d sadas '

# %%
t.rstrip() # Only Trailing Spaces stripped
# Out:
# '    ds   dsa  d sadas'

# %% [markdown]
# 9. Replace a string character by another character by taking your own example

# %%
str = 'abc'
str2 = str.replace('a', 'e')
str2
# Out:
# 'ebc'

# %% [markdown]
# 10. Try to give a definition of string center function with an example
#
# String 'Center' function returns a centered string of length width.

# %%
g = 'WASIQ'
g.center(30,'z')
# Out:
# 'zzzzzzzzzzzzWASIQzzzzzzzzzzzzz'

# %% [markdown]
# 11. Write your definition of compiler and interpretor without copy paste from internet
#
# In simple words, Compiler scans the program written and translates this into code that machine can understand whereas Interpreter takes one single line of code at a time. This basically means that compiler generates an intermediate machine code whereas interpreter doesn't.
#
# * Example of Programming Languages that use Compiler are C, C++, Java
# * Example of Programming Languages that use Interpreter are JavaScript, Ruby
#
# 12. Python is an interpreted or compile language. Give a clear answer with your understanding
#
# In various books of python programming, it is mentioned that python language is interpreted. But that is half correct the python program is first compiled and then interpreted. The compilation part is hidden from the programmer thus, many programmers believe that it is an interpreted language. The compilation part is done first when we execute our code and this will generate byte code and internally this byte code gets converted by the python virtual machine(p.v.m) according to the underlying platform(machine+operating system).
#
# 13. Try to write a use case of python with your understanding
#
# Some Use Cases of Python:
#
# * Data Science
# * Data Analysis
# * Game Development
# * Web Applications
# * Software Development
# * Web Scraping
# * Internet of Things

# %% [markdown]
# # Class - 5 `List, Tuples, Dict, Set`
#
# ## 21-May-2022
#
# ## List

# %%
l = [1,2,3,4,5, "sudh" , 45.67, True]
l
# Out:
# [1, 2, 3, 4, 5, 'sudh', 45.67, True]

# %%
l[0]
# Out:
# 1

# %%
l[-1]
# Out:
# True

# %%
len(l)
# Out:
# 8

# %%
l[0:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
l[::-1]
# Out:
# [True, 45.67, 'sudh', 5, 4, 3, 2, 1]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'sudh', 45.67, True]

# %%
l[0:100: 2]
# Out:
# [1, 3, 5, 45.67]

# %%
l[0:8: -1]
# Out:
# []

# %%
l[:3]
# Out:
# [1, 2, 3]

# %%
l + ['sudh']
# Out:
# [1, 2, 3, 4, 5, 'sudh', 45.67, True, 'sudh']

# %%
l*2
# Out:
# [1, 2, 3, 4, 5, 'sudh', 45.67, True, 1, 2, 3, 4, 5, 'sudh', 45.67, True]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'sudh', 45.67, True]

# %%
60 in l
# Out:
# False

# %%
2 in l
# Out:
# True

# %%
max(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [106], in <cell line: 1>()
# ----> 1 max(l)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
l1 = [3, 4, 5, 6, 6]
l1
# Out:
# [3, 4, 5, 6, 6]

# %%
max(l1)
# Out:
# 6

# %%
l2 = ["Wasiq", "AMU", "Aligarh"]
l2
# Out:
# ['Wasiq', 'AMU', 'Aligarh']

# %%
max(l2)
# Out:
# 'Wasiq'

# %%
min(l1)
# Out:
# 3

# %%
min(l2)
# Out:
# 'AMU'

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'sudh', 45.67, True]

# %%
l.append("kumar")

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'sudh', 45.67, True, 'kumar']

# %%
l.pop(0)
# Out:
# 1

# %%
l
# Out:
# [2, 3, 4, 5, 'sudh', 45.67, True, 'kumar']

# %%
l.reverse()

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 5, 4, 3, 2]

# %%
l.append ([1,2,3,4])
l
# Out:
# ['kumar', True, 45.67, 'sudh', 5, 4, 3, 2, [1, 2, 3, 4]]

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [121], in <cell line: 1>()
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'bool' and 'str'

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 5, 4, 3, 2, [1, 2, 3, 4]]

# %%
l1
# Out:
# [3, 4, 5, 6, 6]

# %%
l1.sort()

# %%
l1
# Out:
# [3, 4, 5, 6, 6]

# %%
l3 = [8, 98, 34, 23, 1, 0]
l3
# Out:
# [8, 98, 34, 23, 1, 0]

# %%
l3.sort(reverse= True)
l3
# Out:
# [98, 34, 23, 8, 1, 0]

# %%
l1 = [2,3,4]
l2 = [6,7,8]
l3 = [3,2,4]

l4 = [l1, l2, l3]
l4
# Out:
# [[2, 3, 4], [6, 7, 8], [3, 2, 4]]

# %%
l4[2][1]
# Out:
# 2

# %%
l4[2][1]
# Out:
# 2

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 5, 4, 3, 2, [1, 2, 3, 4]]

# %%
l.count(2)
# Out:
# 1

# %%
l5 = [3, 4, 5, 3, 3, 3]
l5.count(3)
# Out:
# 4

# %%
l1=[1,2,3]
l2=[4,5,6]
l3=[7,8,9]

l4=[l1,l2,l3]

l4.count(3)
# Out:
# 0

# %%
l4
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 5, 4, 3, 2, [1, 2, 3, 4]]

# %%
l.append("iNeuron")

# %%
l
# Out:
# ['kumar', True, 45.67, 'sudh', 5, 4, 3, 2, [1, 2, 3, 4], 'iNeuron']

# %%
l.append([4,56 , "sudh"])
l
# Out:
# ['kumar',
#  True,
#  45.67,
#  'sudh',
#  5,
#  4,
#  3,
#  2,
#  [1, 2, 3, 4],
#  'iNeuron',
#  [4, 56, 'sudh']]

# %%
l.extend("sudh")

# %%
l
# Out:
# ['kumar',
#  True,
#  45.67,
#  'sudh',
#  5,
#  4,
#  3,
#  2,
#  [1, 2, 3, 4],
#  'iNeuron',
#  [4, 56, 'sudh'],
#  's',
#  'u',
#  'd',
#  'h']

# %%
l.extend("sudh")

# %%
l6 = [1,2,3]

l6.append([4,5,6])
l6
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
l6.extend(45)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [153], in <cell line: 1>()
# ----> 1 l6.extend(45)
#
# TypeError: 'int' object is not iterable

# %%
l6.append(45)
l6
# Out:
# [1, 2, 3, [4, 5, 6], 45]

# %%
l6.extend([56,34,21])
l6
# Out:
# [1, 2, 3, [4, 5, 6], 45, 56, 34, 21]

# %%
l6.extend("sudh")
l6
# Out:
# [1, 2, 3, [4, 5, 6], 45, 56, 34, 21, 's', 'u', 'd', 'h']

# %%
l6.index(1)
# Out:
# 0

# %%
l7  = [1,2,3,4,55,6,6,7]
l7
# Out:
# [1, 2, 3, 4, 55, 6, 6, 7]

# %%
l7.index(6)
# Out:
# 5

# %%
l = [1,2,3,4,5]
l.append(45)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 45]

# %%
l.insert(1 , [1,2,34])
l
# Out:
# [1, [1, 2, 34], 2, 3, 4, 5, 45]

# %%
l.insert(5,"sudh")
l
# Out:
# [1, [1, 2, 34], 2, 3, 4, 'sudh', 5, 45]

# %%
l.pop()
l
# Out:
# [1, [1, 2, 34], 2, 3, 4, 'sudh', 5]

# %%
l.pop(2)
l
# Out:
# [1, [1, 2, 34], 3, 4, 'sudh', 5]

# %%
l.remove(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [166], in <cell line: 1>()
# ----> 1 l.remove(100)
#
# ValueError: list.remove(x): x not in list

# %%
l.remove(4)
l
# Out:
# [1, [1, 2, 34], 3, 'sudh', 5]

# %%
l.remove(3)
l
# Out:
# [1, [1, 2, 34], 'sudh', 5]

# %%
l = [1,2,3,4]
l
# Out:
# [1, 2, 3, 4]

# %%
l[2] ="sudh"
l
# Out:
# [1, 2, 'sudh', 4]

# %%
s = "iNeuron"
s[2] = 'z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [171], in <cell line: 2>()
#       1 s = "iNeuron"
# ----> 2 s[2] = 'z'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## Tuple

# %%
t = (4,5,6,7,"sudh" ,45.67, True)
t
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 4

# %%
t[0:4]
# Out:
# (4, 5, 6, 7)

# %%
t[-1]
# Out:
# True

# %%
t
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True)

# %%
t[0:6: 2]
# Out:
# (4, 6, 'sudh')

# %%
t[0:4: -1]
# Out:
# ()

# %%
l = [1, 2, 3, 456, 78]

# %%
l
# Out:
# [1, 2, 3, 456, 78]

# %%
l[2] = "kumar"
l
# Out:
# [1, 2, 'kumar', 456, 78]

# %%
t
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True)

# %%
t[2] = "sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [184], in <cell line: 1>()
# ----> 1 t[2] = "sudh"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = (3,4,5,6)
t1
# Out:
# (3, 4, 5, 6)

# %%
t
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True)

# %%
t + t1
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True, 3, 4, 5, 6)

# %%
t.count(3)
# Out:
# 0

# %%
t.count(4)
# Out:
# 1

# %%
t.index(5)
# Out:
# 1

# %%
t = t+t1
t
# Out:
# (4, 5, 6, 7, 'sudh', 45.67, True, 3, 4, 5, 6)

# %%
t = (3,4,56,7, "sudh")

# %%
t2 = list(t)
t2
# Out:
# [3, 4, 56, 7, 'sudh']

# %%
tuple(t2)
# Out:
# (3, 4, 56, 7, 'sudh')

# %% [markdown]
# ## Dictionary
#
# It stores in `{ }`

# %%
d = {}
type(d)
# Out:
# dict

# %%
d1 = {1}
type(d1)
# Out:
# set

# %%
d2 = { 'key1' : "value"  , 234 : "xyz" , "name" : "sudh" , "no" : 34324345 }
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}

# %%
type(d2)
# Out:
# dict

# %%
d2['name']
# Out:
# 'sudh'

# %%
d2[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [203], in <cell line: 1>()
# ----> 1 d2[1]
#
# KeyError: 1

# %%
d2['no']
# Out:
# 34324345

# %%
d3 = {'name': "sudh" , 'tech' :["python" , "ML" , "DL" , "NLP","CV" , "Big data" , "data analytics"]}
d3
# Out:
# {'name': 'sudh',
#  'tech': ['python', 'ML', 'DL', 'NLP', 'CV', 'Big data', 'data analytics']}

# %%
"python" in d3['tech']
# Out:
# True

# %%
d4 = {"name" :"iNeuron" , "contact_info" : 345345 , "name":"sudh"}
d4
# Out:
# {'name': 'sudh', 'contact_info': 345345}

# %%
d4["name1"] = "xyz"
d4
# Out:
# {'name': 'sudh', 'contact_info': 345345, 'name1': 'xyz'}

# %%
d4['k2'] = d2
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}

# %%
d4
# Out:
# {'name': 'sudh',
#  'contact_info': 345345,
#  'name1': 'xyz',
#  'k2': {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}}

# %%
d4['k2']['no']
# Out:
# 34324345

# %%
d5 = {_: "sdfsd"}
d5[_]
# Out:
# 'sdfsd'

# %%
d6 = {(1,2,34) : "fsdfs"}
d6[(1,2,34)]
# Out:
# 'fsdfs'

# %%
d7 = {[1,2,3,4] : "fasdfasfas"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [215], in <cell line: 1>()
# ----> 1 d7 = {[1,2,3,4] : "fasdfasfas"}
#
# TypeError: unhashable type: 'list'

# %%
d8 = {{3:4} : "fsdfs"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [216], in <cell line: 1>()
# ----> 1 d8 = {{3:4} : "fsdfs"}
#
# TypeError: unhashable type: 'dict'

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}

# %%
d3
# Out:
# {'name': 'sudh',
#  'tech': ['python', 'ML', 'DL', 'NLP', 'CV', 'Big data', 'data analytics']}

# %%
d2 + d3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [220], in <cell line: 1>()
# ----> 1 d2 + d3
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}

# %%
d2.keys()
# Out:
# dict_keys(['key1', 234, 'name', 'no'])

# %%
d2.values()
# Out:
# dict_values(['value', 'xyz', 'sudh', 34324345])

# %%
d2.items()
# Out:
# dict_items([('key1', 'value'), (234, 'xyz'), ('name', 'sudh'), ('no', 34324345)])

# %% [markdown]
# ## Set
#
# Set also stores in `{ }` but it doesn't require *key* and *values* as dictionary / dict. It gives only unique values. Slicing does not work in set,

# %%
s = {3,4,5,6,7,8}
s
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
type(s)
# Out:
# set

# %%
s1 = {3, 4,4, 5, 6,6, 7,7, 8,8, 9,9, 0,0,0}
s1
# Out:
# {0, 3, 4, 5, 6, 7, 8, 9}

# %%
s2 = { 3245, 4545, 6456, 5645, 675, 6234, 345}
s2
# Out:
# {345, 675, 3245, 4545, 5645, 6234, 6456}

# %%
s3 = {"sudh", 324, 34, 12, 645, 12, 5, 'b', '6'}
s3
# Out:
# {12, 324, 34, 5, '6', 645, 'b', 'sudh'}

# %%
s3[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [230], in <cell line: 1>()
# ----> 1 s3[0]
#
# TypeError: 'set' object is not subscriptable

# %%
list(s3)
# Out:
# ['6', 34, 324, 'sudh', 645, 5, 'b', 12]

# %%
tuple(s3)
# Out:
# ('6', 34, 324, 'sudh', 645, 5, 'b', 12)

# %%
l = [2,3,4,5656,7,6,7,7,7,77,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7,7]
l
# Out:
# [2,
#  3,
#  4,
#  5656,
#  7,
#  6,
#  7,
#  7,
#  7,
#  77,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7]

# %%
l = list(set(l))
l
# Out:
# [2, 3, 4, 6, 7, 77, 5656]

# %%
s2
# Out:
# {345, 675, 3245, 4545, 5645, 6234, 6456}

# %%
s2.add(34)
s2
# Out:
# {34, 345, 675, 3245, 4545, 5645, 6234, 6456}

# %%
s2.add([1,2,3,4,5])
s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [239], in <cell line: 1>()
# ----> 1 s2.add([1,2,3,4,5])
#       2 s2
#
# TypeError: unhashable type: 'list'

# %%
s = {(1,2,3,4,5) , 3,4,45,65,6}
s
# Out:
# {(1, 2, 3, 4, 5), 3, 4, 45, 6, 65}

# %%
s1 = {[1,2,3,4] , 345 ,345}
s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [241], in <cell line: 1>()
# ----> 1 s1 = {[1,2,3,4] , 345 ,345}
#       2 s2
#
# TypeError: unhashable type: 'list'

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 3, 4, 45, 6, 65}

# %%
s.remove(35345)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [243], in <cell line: 1>()
# ----> 1 s.remove(35345)
#
# KeyError: 35345

# %%
s
# Out:
# {(1, 2, 3, 4, 5), 3, 4, 45, 6, 65}

# %%
s.discard(3452646)
s
# Out:
# {(1, 2, 3, 4, 5), 3, 4, 45, 6, 65}

# %%
s.pop()
s
# Out:
# {(1, 2, 3, 4, 5), 4, 45, 6}

# %%
type(s)
# Out:
# set

# %%
l = list(s)
l
# Out:
# [4, 6, (1, 2, 3, 4, 5), 45]

# %%
set(l)
# Out:
# {(1, 2, 3, 4, 5), 4, 45, 6}

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345}

# %%
d2["key4"] = "sdfsf"

# %%
d2
# Out:
# {'key1': 'value', 234: 'xyz', 'name': 'sudh', 'no': 34324345, 'key4': 'sdfsf'}

# %%
d2["key1"]  = "ineuron"
d2
# Out:
# {'key1': 'ineuron',
#  234: 'xyz',
#  'name': 'sudh',
#  'no': 34324345,
#  'key4': 'sdfsf'}

# %%
l3
# Out:
# [7, 8, 9]

# %%
l3.sort(reverse=True) 
l3
# Out:
# [9, 8, 7]

# %%
s = "surya"
s1 = "su"

# %%
s+s1
# Out:
# 'suryasu'

# %%
d2
# Out:
# {'key1': 'ineuron',
#  234: 'xyz',
#  'name': 'sudh',
#  'no': 34324345,
#  'key4': 'sdfsf'}

# %%
d2.fromkeys("k1")
# Out:
# {'k': None, '1': None}

# %%
d2['k'] = "sudh"
d2
# Out:
# {'key1': 'ineuron',
#  234: 'xyz',
#  'name': 'sudh',
#  'no': 34324345,
#  'key4': 'sdfsf',
#  'k': 'sudh'}

# %% [markdown]
# **Write a programme to find the area of a triangle**
#
# $$\text{Area of $\Delta$} = \sqrt{s(s-s_1)(s-s_2)(s-s_3)}$$
#
# where, $s = \frac{s_1 + s_2 + s_3}{2}$

# %%
# Area of triangle
side1 = float(input("Enter first side of triangle : "))
side2 = float(input("Enter second side of triangle: "))
side3 = float(input("Enter third side of triangle : "))

s = (side1 + side2 + side3) / 2

area = (s*(s-side1)*(s-side2)*(s-side3)) ** 0.5

print("Area of the triangle is -: ", area)
# Out:
# Enter first side of triangle : 34
# Enter second side of triangle: 56
# Enter third side of triangle : 34
# Area of the triangle is -:  540.0444426156055

# %%
l = [1,2,3,4,5]
l
# Out:
# [1, 2, 3, 4, 5]

# %%
l.insert(-1 , "sudh") ; l
# Out:
# [1, 2, 3, 4, 'sudh', 5]

# %%
t = ( 4,5,6)
t1 =( 6 )

# %%
type(t1)
# Out:
# int

# %%
#Question
D_NEW = {'name':'Vishnu','title':'Data Analyst','course':'FSDS'}
D_NEW['key1'] = D_NEW

print(D_NEW['name'])
print()
print(D_NEW['key1'])
# Out:
# Vishnu
#
# {'name': 'Vishnu', 'title': 'Data Analyst', 'course': 'FSDS', 'key1': {...}}

# %%
print(D_NEW['name'])
print()
print(D_NEW['key1'])
# Out:
# Vishnu
#
# {'name': 'Vishnu', 'title': 'Data Analyst', 'course': 'FSDS', 'key1': {...}}

# %%
D_NEW
# Out:
# {'name': 'Vishnu', 'title': 'Data Analyst', 'course': 'FSDS', 'key1': {...}}

# %%
t1 = (3,5,67.8,789,'876dfghj')
t = t+t1
print("Type of t : ", type(t))
print()

t.count(3)
t2 = list(t)
print("t2 :", t2)
print()

tuple(t2)

print("Type of t2 : ", type(t2))
# Out:
# Type of t :  <class 'tuple'>
#
# t2 : [4, 5, 6, 3, 5, 67.8, 789, '876dfghj', 3, 5, 67.8, 789, '876dfghj']
#
# Type of t2 :  <class 'list'>

# %%
s = {3,4,5,6,7,7}
s
# Out:
# {3, 4, 5, 6, 7}

# %%
list(s)[0]
# Out:
# 3

# %%
round(34.5656567 , 2)
# Out:
# 34.57

# %%
###### MY QUESTIONS #####
d4={"name":"iNeuron", "contact_info":34345,"name":"rupe"}
d4['loc']='Calgary'
d4['check'] = d4

#### LOOP ####
print("LOOP")
print(d4['check'])
print()

#### TYPE ####

print("TYPE")
print(d4.keys())
print(d4.items())
print(type(d2.keys()))
print(type(d2.items()))
print()

#### SIGNATURE #########
print("SIGNATURE")
n=[4, 5, 7, 9, 2, 3, 4, 5, 2, 1, 9, 6, 7, 0]
print(n.pop())

print(n.sort())
# Out:
# LOOP
# {'name': 'rupe', 'contact_info': 34345, 'loc': 'Calgary', 'check': {...}}
#
# TYPE
# dict_keys(['name', 'contact_info', 'loc', 'check'])
# dict_items([('name', 'rupe'), ('contact_info', 34345), ('loc', 'Calgary'), ('check', {'name': 'rupe', 'contact_info': 34345, 'loc': 'Calgary', 'check': {...}})])
# <class 'dict_keys'>
# <class 'dict_items'>
#
# SIGNATURE
# 0
# None

# %%
d2 = { "k1" :"fsdfs" , "k2 " : [4,5,56]}
d2
# Out:
# {'k1': 'fsdfs', 'k2 ': [4, 5, 56]}

# %%
l = d2.keys()
l
# Out:
# dict_keys(['k1', 'k2 '])

# %%
list(l)[0]
# Out:
# 'k1'

# %%
s = {1, 2, None, 3,4}
s
# Out:
# {1, 2, 3, 4, None}

# %%
l = [10,2,3,4,5,6,7,[11,22,33,44,55,66],111,222,333,'umesh']
l
# Out:
# [10, 2, 3, 4, 5, 6, 7, [11, 22, 33, 44, 55, 66], 111, 222, 333, 'umesh']

# %%
l.remove(10)
l
# Out:
# [2, 3, 4, 5, 6, 7, [11, 22, 33, 44, 55, 66], 111, 222, 333, 'umesh']

# %% [markdown]
# # Task - 2
#
# `l = [3,4,5,6,7 , [23,456,67,8,78,78] , [345,56,87,8,98,9] , (234,6657,6) , {"key1" :"sudh" , 234:[23,45,656]}]`
#
# 1. Try to reverse a list
# 2. try to access 234 out of this list
# 3. try to access 456
# 4. Try to extract only a list collection form list l
# 5. Try to extract "sudh"
# 6. Try to list all the key in dict element avaible in list
# 7. Try to extract all the value element form dict available in list
#
# ## Solution Task - 2
#
# 1. Try to reverse a list

# %%
l = [3,4,5,6,7 , [23,456,67,8,78,78] , [345,56,87,8,98,9] , (234,6657,6) , {"key1" :"sudh" , 234:[23,45,656]}]
l.reverse()
l
# Out:
# [{'key1': 'sudh', 234: [23, 45, 656]},
#  (234, 6657, 6),
#  [345, 56, 87, 8, 98, 9],
#  [23, 456, 67, 8, 78, 78],
#  7,
#  6,
#  5,
#  4,
#  3]

# %% [markdown]
# 2. Try to access 234 out of this list

# %%
l = [3,4,5,6,7 , [23,456,67,8,78,78] , [345,56,87,8,98,9] , (234,6657,6) , {"key1" :"sudh" , 234:[23,45,656]}]

l[7][0]
# Out:
# 234

# %% [markdown]
# 3. Try to access 456

# %%
l[5][1]
# Out:
# 456

# %% [markdown]
# 4. Try to extract only a list collection form list l

# %%
indices = [5, 6]

extracted_elements = [l[index] for index in indices]
extracted_elements
# Out:
# [[23, 456, 67, 8, 78, 78], [345, 56, 87, 8, 98, 9]]

# %% [markdown]
# 5. Try to extract "sudh"

# %%
l[-1]['key1']
# Out:
# 'sudh'

# %% [markdown]
# 6. Try to list all the key in dict element avaible in list

# %%
l[-1].keys()
# Out:
# dict_keys(['key1', 234])

# %% [markdown]
# 7. Try to extract all the value element form dict available in list

# %%
l[-1].values()
# Out:
# dict_values(['sudh', [23, 45, 656]])
