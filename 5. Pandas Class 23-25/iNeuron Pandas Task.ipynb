# %% [markdown]
# # Pandas Task - I
#
# **Dataset 1 : Agent Performance Data from iNeuron (Real Dataset)**
#
# **Dataset 2 : Agent Login Report**
#
# **https://docs.google.com/spreadsheets/d/1z4EWsGxw0YBQ1-51xZDxYNlB3ngJzg4t/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true**
#
#
# **https://docs.google.com/spreadsheets/d/1z2n8aeFF5GoohQ3KCZw8bKogezpO9l4k/edit?usp=sharing&ouid=118282207943964605599&rtpof=true&sd=true**
# 1. For each and every agent, Find out the weekly average rating for each agent (They workfor 5 days a week and not 7 days. So be careful with that. System will generate 7 records for a week)
# 2. Total Working Days for each Agent from Agent Performance Report
# 3. Total Queries taken by Agents
# 4. Total Feedback received by Agents
# 5. Agent Name who have average rating between 3.5 to 4
# 6. Agent Name who have rating less than 3.5
# 7. Agent Name who have rating more than 4.5
# 8. How many feedback agents have received more than Average
# 9. Average Weekly Response Time for each agent
# 10. Average Weekly Resolution Time for each agent
# 11. List of All Agents Name
# 12. Percentage of Chat on which they have recieved a feedback
# 13. Total Contribution hour for each and every agents weekly basis from Login Report Data
# 14. Total Percentage of Active Hour for a month

# %%
import pandas as pd
df = pd.read_excel(r'E://pycharm.py//Datasets/AgentPerformance.xlsx',skiprows=1)
df.head()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                00:04:20            4.11               9
# 1                00:28:25            3.14               7
# 2                00:11:36            4.55              11
# 3                00:15:46            4.71               7
# ...

# %%
df.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %% [markdown]
# 1. Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave.

# %%
df['date']=pd.to_datetime(df['Date'])

# %%
df.head(2)
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback       date
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30

# %%
df['date_week']=df['date'].dt.isocalendar().week

# %%
df['date_days']=df['date'].dt.day

# %%
df_mean=df.groupby(['Agent Name','date_week'])['Average Rating'].mean().to_frame()

# %%
df_mean
# Out:
#                       Average Rating
# Agent Name date_week
# Abhishek   26               0.000000
#            27               0.000000
#            28               0.000000
#            29               0.000000
#            30               0.000000
# ...                              ...
# Zeeshan    26               0.000000
#            27               1.307143
#            28               2.948571
#            29               3.180000
#            30               2.760000
#
# [350 rows x 1 columns]

# %% [markdown]
# 2. Total working days for each agents

# %%
df.groupby('Agent Name')['date_days'].count()
# Out:
# Agent Name
# Abhishek         30
# Aditya           30
# Aditya Shinde    30
# Aditya_iot       30
# Amersh           30
#                  ..
# Uday Mishra      30
# Vasanth P        30
# Vivek            30
# Wasim            30
# Zeeshan          30
# Name: date_days, Length: 70, dtype: int64

# %% [markdown]
# 3. Total query that you have taken

# %%
df.groupby('Agent Name')['Total Chats'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    277
# Aditya_iot       231
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             44
# Wasim            433
# Zeeshan          542
# Name: Total Chats, Length: 70, dtype: int64

# %% [markdown]
# 4. Total Feedback that you have received

# %%
df.groupby('Agent Name')['Total Feedback'].sum()
# Out:
# Agent Name
# Abhishek           0
# Aditya             0
# Aditya Shinde    153
# Aditya_iot       131
# Amersh             0
#                 ...
# Uday Mishra        0
# Vasanth P          0
# Vivek             20
# Wasim            284
# Zeeshan          335
# Name: Total Feedback, Length: 70, dtype: int64

# %% [markdown]
# 5. Agent name who have average rating between 3.5 to 4

# %%
df[(df['Average Rating']>3.5) & (df['Average Rating']<=4)]['Agent Name']
# Out:
# 4                    Swati
# 10             Manjunatha A
# 73      Boktiar Ahmed Bappy
# 76            Prateek _iot
# 78            Nandani Gupta
#                ...
# 1941         Jawala Prakash
# 2018          Sanjeev Kumar
# 2021          Aditya Shinde
# 2023       Deepranjan Gupta
# 2097          Sanjeev Kumar
# Name: Agent Name, Length: 111, dtype: object

# %% [markdown]
# 6. Agent name who have rating lesss then 3.5

# %%
df[(df['Average Rating']<3.5)]['Agent Name']
# Out:
# 1            Nandani Gupta
# 19        Hitesh Choudhary
# 20              Sanjeevan
# 21                Anirudh
# 22        Shiva Srivastava
#                ...
# 2155     Sowmiya Sivakumar
# 2156               Nitin M
# 2157                Vivek
# 2158         Ayushi Mishra
# 2159    Chaitra K Hiremath
# Name: Agent Name, Length: 1474, dtype: object

# %% [markdown]
# 7. Agent name who have rating more then 4.5

# %%
df[(df['Average Rating']>4.5)]['Agent Name']
# Out:
# 2               Ameya Jain
# 3            Mahesh Sarade
# 5                  Mukesh
# 6          Saikumarreddy N
# 7            Sanjeev Kumar
#                ...
# 2100        Shubham Sharma
# 2101         Jaydeep Dixit
# 2102    Shivananda Sonwane
# 2103        Khushboo Priya
# 2104       Hrisikesh Neogi
# Name: Agent Name, Length: 307, dtype: object

# %% [markdown]
# 8. How many feedaback agents have received more then 4.5 average

# %%
df.groupby('Agent Name')['Total Feedback'].mean()>4.5
# Out:
# Agent Name
# Abhishek         False
# Aditya           False
# Aditya Shinde     True
# Aditya_iot       False
# Amersh           False
#                  ...
# Uday Mishra      False
# Vasanth P        False
# Vivek            False
# Wasim             True
# Zeeshan           True
# Name: Total Feedback, Length: 70, dtype: bool

# %% [markdown]
# 9. Average weekly response time for each agent

# %%
def get_seconds(time_str):
    #print('Time in hh:mm:ss:', time_str)
    # split in hh, mm, ss
    hh, mm, ss = time_str.split(':')
    return int(hh) * 3600 + int(mm) * 60 + int(ss)

# %%
avg_response_sec=[]
for t in df['Average Response Time']:
    avg_response_sec.append(get_seconds(t))
avg_response_sec
df['avg_response_sec'] = avg_response_sec

# %%
df.head()
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
# 2                00:11:36            4.55              11 2022-07-30
# 3                00:15:46            4.71               7 2022-07-30
# 4                00:16:33            3.67               6 2022-07-30
#
#    date_week  date_days  avg_response_sec
# 0         30         30                38
# ...

# %%
df.groupby(['Agent Name','date_week'])['avg_response_sec'].mean()
# Out:
# Agent Name  date_week
# Abhishek    26             0.000000
#             27             0.000000
#             28             0.000000
#             29             0.000000
#             30             0.000000
#                             ...
# Zeeshan     26             0.000000
#             27            23.571429
#             28           123.428571
#             29            62.857143
#             30            63.833333
# Name: avg_response_sec, Length: 350, dtype: float64

# %% [markdown]
# 10. Average weekely resolution time for each agents

# %%
avg_resolution_time_sec=[]
for t in df['Average Resolution Time']:
    avg_resolution_time_sec.append(get_seconds(t))
avg_resolution_time_sec
df['avg_resolution_time_sec'] = avg_resolution_time_sec
df.head()
# Out:
#    SL No        Date     Agent Name  Total Chats Average Response Time  \
# 0      1  2022-07-30   Prerna Singh           11              00:00:38
# 1      2  2022-07-30  Nandani Gupta           11              00:01:15
# 2      3  2022-07-30     Ameya Jain           14              00:00:30
# 3      4  2022-07-30  Mahesh Sarade           14              00:01:04
# 4      5  2022-07-30         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback       date  \
# 0                00:04:20            4.11               9 2022-07-30
# 1                00:28:25            3.14               7 2022-07-30
# 2                00:11:36            4.55              11 2022-07-30
# 3                00:15:46            4.71               7 2022-07-30
# 4                00:16:33            3.67               6 2022-07-30
#
#    date_week  date_days  avg_response_sec  avg_resolution_time_sec
# ...

# %%
df.groupby(['Agent Name','date_week'])['avg_resolution_time_sec'].mean()
# Out:
# Agent Name  date_week
# Abhishek    26             0.000000
#             27             0.000000
#             28             0.000000
#             29             0.000000
#             30             0.000000
#                             ...
# Zeeshan     26             0.000000
#             27           323.000000
#             28           984.285714
#             29           794.285714
#             30           773.500000
# Name: avg_resolution_time_sec, Length: 350, dtype: float64

# %% [markdown]
# 11. List of all agents name

# %%
set(df['Agent Name'])
# Out:
# {'Abhishek ',
#  'Aditya ',
#  'Aditya Shinde',
#  'Aditya_iot ',
#  'Amersh ',
#  'Ameya Jain',
#  'Anirudh ',
#  'Ankit Sharma',
#  'Ankitjha ',
#  'Anurag Tiwari',
#  'Aravind ',
#  'Ashad Nasim',
#  'Ashish ',
#  'Ayushi Mishra',
#  'Bharath ',
#  'Boktiar Ahmed Bappy',
#  'Chaitra K Hiremath',
#  'Deepranjan Gupta',
#  'Dibyanshu ',
#  'Harikrishnan Shaji',
#  'Hitesh Choudhary',
#  'Hrisikesh Neogi',
#  'Hyder Abbas',
#  'Ineuron Intelligence ',
#  'Ishawant Kumar',
#  'Jawala Prakash',
#  'Jayant Kumar',
#  'Jaydeep Dixit',
#  'Khushboo Priya',
#  'Madhulika G',
#  'Mahak ',
#  'Mahesh Sarade',
#  'Maitry ',
#  'Maneesh ',
#  'Manjunatha A',
#  'Mithun S',
#  'Mukesh ',
#  'Mukesh Rao ',
#  'Muskan Garg',
#  'Nandani Gupta',
#  'Nishtha Jain',
#  'Nitin M',
#  'Prabir Kumar Satapathy',
#  'Prateek _iot ',
#  'Prerna Singh',
#  'Rishav Dash',
#  'Rohan ',
#  'Saif Khan',
#  'Saikumarreddy N',
#  'Samprit ',
#  'Sandipan Saha',
#  'Sanjeev Kumar',
#  'Sanjeevan ',
# ...

# %% [markdown]
# 12. percentage of chat on which they have received a feedback

# %%
df.groupby(['Agent Name','Total Chats'])['Total Feedback'].sum()
# Out:
# Agent Name     Total Chats
# Abhishek       0               0
# Aditya         0               0
# Aditya Shinde  0               0
#                8               7
#                14              9
#                               ..
# Zeeshan        36             28
#                37             25
#                41             25
#                46             28
#                92             35
# Name: Total Feedback, Length: 638, dtype: int64

# %% [markdown]
# 13. Total contributation hour for each and every agents weekly basis

# %% [markdown]
# ### Second Dataset

# %%
df1 = pd.read_excel(r'E://pycharm.py//Datasets/Agent_Login_Report.xls',skiprows=2)
df1.head()
# Out:
#    SL No               Agent       Date   Login Time  Logout Time  Duration
# 0      1  Shivananda Sonwane  30-Jul-22  03:35:29 PM  05:39:39 PM  02:04:10
# 1      2      Khushboo Priya  30-Jul-22  03:06:59 PM  03:07:16 PM  00:00:17
# 2      3       Nandani Gupta  30-Jul-22  03:04:24 PM  05:31:07 PM  02:26:42
# 3      4     Hrisikesh Neogi  30-Jul-22  02:34:29 PM  03:19:35 PM  00:45:06
# 4      5             Mukesh   30-Jul-22  02:03:15 PM  03:11:52 PM  01:08:36

# %%
df1.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
df1['Date'] = pd.to_datetime(df1['Date'])

# %%
df1['week'] = df1['Date'].dt.isocalendar().week

# %%
Total_duration_secs=[]
for t in df1['Duration']:
    Total_duration_secs.append(get_seconds(t))
Total_duration_secs
df1['Total_duration_secs'] = Total_duration_secs

# %%
df1.dtypes
# Out:
# SL No                           int64
# Agent                          object
# Date                   datetime64[ns]
# Login Time                     object
# Logout Time                    object
# Duration                       object
# week                           UInt32
# Total_duration_secs             int64
# dtype: object

# %%
df1['hours']=df1['Total_duration_secs']/3600

# %%
df1.groupby(['Agent','week'])['hours'].mean()
# Out:
# Agent          week
# Aditya Shinde  30        0.036111
# Aditya_iot     29        2.031759
#                30        1.605972
# Amersh         30        0.765972
# Ameya Jain     29        3.440437
#                           ...
# Tarun          26      514.138889
# Wasim          29        2.180617
#                30        2.595783
# Zeeshan        29        4.071250
#                30        6.165278
# Name: hours, Length: 89, dtype: float64

# %% [markdown]
# 14. total percentage of active hour for a month

# %%
df1['month'] = df1['Date'].dt.month
df1
# Out:
#      SL No               Agent       Date   Login Time  Logout Time  \
# 0        1  Shivananda Sonwane 2022-07-30  03:35:29 PM  05:39:39 PM
# 1        2      Khushboo Priya 2022-07-30  03:06:59 PM  03:07:16 PM
# 2        3       Nandani Gupta 2022-07-30  03:04:24 PM  05:31:07 PM
# 3        4     Hrisikesh Neogi 2022-07-30  02:34:29 PM  03:19:35 PM
# 4        5             Mukesh  2022-07-30  02:03:15 PM  03:11:52 PM
# ..     ...                 ...        ...          ...          ...
# 995    996        Manjunatha A 2022-07-20  09:03:51 AM  03:02:28 PM
# 996    997            Bharath  2022-07-20  09:00:49 AM  03:01:32 PM
# 997    998      Khushboo Priya 2022-07-20  08:59:20 AM  02:26:55 PM
# 998    999        Nishtha Jain 2022-07-20  08:43:55 AM  02:00:33 PM
# 999   1000              Tarun  2022-07-01  01:52:47 AM  12:01:07 PM
#
#       Duration  week  Total_duration_secs       hours  month
# 0     02:04:10    30                 7450    2.069444      7
# ...

# %%
100*df1['hours']/df1.groupby('month')['hours'].transform('sum')
# Out:
# 0       0.094930
# 1       0.000217
# 2       0.112158
# 3       0.034481
# 4       0.052447
#          ...
# 995     0.274176
# 996     0.275782
# 997     0.250437
# 998     0.242078
# 999    23.584737
# Name: hours, Length: 1000, dtype: float64

# %% [markdown]
# # TASKS - II
#
# **https://drive.google.com/drive/folders/1zRQjEqbUWCIrBOk3rqMXI_5luwfN0QnY**
#
# ## Fitbit Dataset
#
# 1. Read this dataset in pandas , mysql and mongodb
# 2. while creting a table in mysql dont use manual approach to create it  ,always use a automation to create a table in mysql
#
#         # hint - use csvkit library to automate this task and to load a data in bulk in you mysql
# 3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format
# 4. Find out in this data that how many unique id's we have
# 5. which id is one of the active id that you have in whole dataset
# 6. how many of them have not logged there activity find out in terms of number of ids
# 7. Find out who is the laziest person id that we have in dataset
# 8. Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset
# 9. how many person are not a regular person with respect to activity try to find out those
# 10. who is the thired most active person in this dataset find out those in pandas and in sql both .
# 11. who is the 5th most laziest person avilable in dataset find it out
# 12. what is a totla acumulative calories burn for a person find out

# %%
# 1. Read this dataset in pandas , mysql and mongodb
## In pandas
df = pd.read_csv(r'E://pycharm.py//Datasets/FitBit data.csv')
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
#Importing Necessary Files
import pandas as pd
from sqlalchemy import engine
import mysql.connector as conn

# %%
# !pip install PyMySQL

# %%
#Reading Data in SQL
my_db = conn.connect(host = 'localhost', user = 'root', passwd = '12345')
cursor = my_db.cursor()
cursor.execute("create database FitBitdata")

# %%
#Engine Creation
engine = engine.create_engine('mysql+pymysql://root:8067@localhost/FitBitdata')

# %% [markdown]
# ```py
# df.to_sql("FitBitdata", con = engine)
# ```

# %%
#Pushing Data into Mongo DB
import pymongo
import pandas as pd
import json

# %%
client = pymongo.MongoClient("mongodb+srv://gl0427:wasiq123@cluster0.afuprqr.mongodb.net/?retryWrites=true&w=majority")

# %%
data = df.to_dict(orient = 'records')

# %%
data
# Out:
# [{'Id': 1503960366,
#   'ActivityDate': '3/25/2016',
#   'TotalSteps': 11004,
#   'TotalDistance': 7.1100001335144,
#   'TrackerDistance': 7.1100001335144,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.5699999332428,
#   'ModeratelyActiveDistance': 0.46000000834465,
#   'LightActiveDistance': 4.07000017166138,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 33,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 205,
#   'SedentaryMinutes': 804,
#   'Calories': 1819},
#  {'Id': 1503960366,
#   'ActivityDate': '3/26/2016',
#   'TotalSteps': 17609,
#   'TotalDistance': 11.5500001907349,
#   'TrackerDistance': 11.5500001907349,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 6.92000007629395,
#   'ModeratelyActiveDistance': 0.730000019073486,
#   'LightActiveDistance': 3.91000008583069,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 89,
#   'FairlyActiveMinutes': 17,
#   'LightlyActiveMinutes': 274,
# ...

# %%
db = client["FitBitdata"]
print(db)
# Out:
# Database(MongoClient(host=['ac-o1iqye4-shard-00-00.afuprqr.mongodb.net:27017', 'ac-o1iqye4-shard-00-01.afuprqr.mongodb.net:27017', 'ac-o1iqye4-shard-00-02.afuprqr.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-t47wa6-shard-0', tls=True), 'FitBitdata')

# %%
db.FitBit.insert_many(data)

# %%
#3. Convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format

df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df['ActivityDate']= pd.to_datetime(df['ActivityDate'])

# %%
df.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %%
#4. Find out in this data that how many unique id's we have 
len(df['Id'].unique()) #There are 35 unique id's
# Out:
# 35

# %%
#5. which id is one of the active id that you have in whole dataset 
df["TotalActiveMinutes"] = (df['VeryActiveMinutes'] + df['FairlyActiveMinutes'] + df['LightlyActiveMinutes'])

# %%
df.sort_values('TotalActiveMinutes', ascending=False).iloc[[0]]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 139  2891001357   2016-04-02        4126           3.22              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 139                  3.218688                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 139                 3.22                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 139                    0                   720               720      2881
#
#      TotalActiveMinutes
# 139                 720

# %%
#6. how many of them have not logged there activity find out in terms of number of ids 
len(df[df['TotalActiveMinutes']== 0]) #There are total 68 id's that have not logged their activity
# Out:
# 68

# %%
#7. Find out who is the laziest person id that we have in dataset 
df[df['Calories']>0].sort_values(['Calories']).reset_index().iloc[[0]] #Person with ID 1503960366 is the laziest person
# Out:
#    index          Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0     18  1503960366   2016-04-12         224           0.14             0.14
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                 0.0                       0.0
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 0.13                      0.0                  0
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                    0                     9                32        50
#
#    TotalActiveMinutes
# 0                   9

# %%
#8. Explore over an internet that how much calories burn is required for a healthy person and 
# find out how many healthy person we have in our dataset 

#According to Internet: As a general guideline, women typically burn about 2,000 calories per day and 
# men burn about 2,500 calories per day. These numbers are often used to determine 

# an approximate food intake for weight maintenance. As we don.t know the exact gender of the person,
# we will take average of both.
#i.e. 2250 calories are required to be burned per day for a healthy person.

len(df[df['Calories']>2250]['Id'].unique()) #So there are 24 persons who are healthy
# Out:
# 24

# %%
#And if we consider the minimum calories of the required calories burnt, then :
len(df[df['Calories']>2000]['Id'].unique())
# Out:
# 30

# %%
#9. how many person are not a regular person with respect to activity try to find out those 
df.groupby('Id')['ActivityDate'].unique()
# Out:
# Id
# 1503960366    [2016-03-25T00:00:00.000000000, 2016-03-26T00:...
# 1624580081    [2016-03-25T00:00:00.000000000, 2016-03-26T00:...
# 1644430081    [2016-04-01T00:00:00.000000000, 2016-04-02T00:...
# 1844505072    [2016-04-01T00:00:00.000000000, 2016-04-02T00:...
# 1927972279    [2016-04-01T00:00:00.000000000, 2016-04-02T00:...
# 2022484408    [2016-04-01T00:00:00.000000000, 2016-04-02T00:...
# 2026352035    [2016-04-01T00:00:00.000000000, 2016-04-02T00:...
# 2320127002    [2016-04-01T00:00:00.000000000, 2016-04-02T00:...
# 2347167796    [2016-03-29T00:00:00.000000000, 2016-03-30T00:...
# 2873212765    [2016-04-01T00:00:00.000000000, 2016-04-02T00:...
# 2891001357    [2016-03-29T00:00:00.000000000, 2016-03-30T00:...
# 3372868164    [2016-04-01T00:00:00.000000000, 2016-04-02T00:...
# 3977333714    [2016-04-01T00:00:00.000000000, 2016-04-02T00:...
# 4020332650    [2016-03-12T00:00:00.000000000, 2016-03-13T00:...
# 4057192912    [2016-03-12T00:00:00.000000000, 2016-03-13T00:...
# ...

# %%
#10. who is the third most active person in this dataset find out those in pandas and in sql both . 
df.sort_values("TotalActiveMinutes", ascending = False).reset_index().iloc[[2]]
# Out:
#    index          Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 2    142  2891001357   2016-04-05        2063           1.61              0.0
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 2                  1.609344                 0.0                       0.0
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 2                 1.61                      0.0                  0
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 2                    0                   630                99      1144
#
#    TotalActiveMinutes
# 2                 630

# %%
#11. who is the 5th most laziest person avilable in dataset find it out 
df.sort_values('TotalSteps').reset_index().iloc[[4]]
# Out:
#    index          Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 4    341  6391747486   2016-04-08           0            0.0              0.0
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 4                       0.0                 0.0                       0.0
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 4                  0.0                      0.0                  0
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 4                    0                     0              1440      1820
#
#    TotalActiveMinutes
# 4                   0

# %%
#12. what is a total Cumulative Calories burn for a person find out 
res = df.groupby('Id',as_index = False).sum()
res[[ "Id", 'Calories']]
# Out:
#             Id  Calories
# 0   1503960366     34128
# 1   1624580081     25705
# 2   1644430081     29164
# 3   1844505072     19391
# 4   1927972279     27048
# 5   2022484408     29704
# 6   2026352035     16266
# 7   2320127002     18385
# 8   2347167796     30320
# 9   2873212765     20349
# 10  2891001357     18187
# 11  3372868164     18603
# 12  3977333714     16777
# 13  4020332650     98412
# 14  4057192912     60913
# 15  4319703577     23931
# 16  4388161847     14442
# 17  4445114986     31617
# 18  4558609924     21962
# 19  4702921684     42322
# 20  5553957443     21630
# 21  5577150313     36303
# 22  6117666160     20993
# 23  6290855005     21656
# 24  6391747486     15868
# 25  6775888955     24523
# 26  6962181067     29249
# 27  7007744171     31525
# 28  7086361926     26124
# 29  8053475328     31825
# 30  8253242879     17556
# 31  8378563200     40274
# 32  8583815059     19130
# 33  8792009665     24884
# 34  8877689391     41414

# %% [markdown]
# ## Superstore_USA
# 1. load this data in sql and in pandas with a relation in sql
# 2. while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table
# 3. Find out how return that we ahve recived and with a product id
# 4. try  to join order and return data both in sql and pandas
# 5. Try to find out how many unique customer that we have
# 6. try to find out in how many regions we are selling a product and who is a manager for a respective region
# 7. find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
# 8. Create a new coulmn and try to find our a diffrence between order date and shipment date
# 9. base on question number 8 find out for which order id we have shipment duration more than 10 days
# 10. Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well
# 11. Gorup by region and find out which region is more profitable
# 12. Try to find out overalll in which country we are giving more didscount
# 13. Give me a list of unique postal code
# 14. which customer segement is more profitalble find it out .
# 15. try to find out the 10th most loss making product catagory .
# 16. Try to find out 10 top  product with highest margins

# %%
#1. Load this data in sql and in pandas with a relation in sql 
#2. While loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table 
import pandas as pd
import xlrd
import csv
import mysql.connector as conn

# %%
mydb = conn.connect(host = 'localhost', user = 'root', passwd = '12345')
cursor = mydb.cursor(buffered=True)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:8067@localhost/superstore')

# %%
orders = pd.read_excel(r"E://pycharm.py//Datasets/SuperStore_USA.xlsx",
                       names =["RowID", "OrderPriority", "Discount", "UnitPrice", "ShippingCost",
                               "CustomerID", "CustomerName", "ShipMode", "CustomerSegment",
                               "ProductCategory", "ProductSub-Category", "ProductContainer",
                               "ProductName", "ProductBase Margin", "Region", "StateorProvince",
                               "City", "PostalCode", "OrderDate", "ShipDate", "Profit", 
                               "Quantityorderednew", "Sales", "OrderID"])
orders.head()
# Out:
#    RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 0  18606  Not Specified      0.01       2.88          0.50           2
# 1  20847           High      0.01       2.84          0.93           3
# 2  23086  Not Specified      0.03       6.68          6.15           3
# 3  23087  Not Specified      0.01       5.68          3.60           3
# 4  23088  Not Specified      0.00     205.99          2.50           3
#
#       CustomerName     ShipMode CustomerSegment  ProductCategory  ...  \
# 0  Janice Fletcher  Regular Air       Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air       Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air       Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air       Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air       Corporate       Technology  ...
#
#     Region StateorProvince       City  PostalCode  OrderDate   ShipDate  \
# ...

# %%
orders.to_sql('orders', con=engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
type(orders)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ```python
# cursor = mydb.cursor()
#
# cursor.execute("SELECT * FROM superstore.orders")
#
# myresult = cursor.fetchall()
#
# for x in myresult:
#     print(x)
# ```

# %% [markdown]
# **To bulk load data in MySQL database, we need to use mannual process which is given below :**
#
# - First to load excel file directly into database, we have to convert it into CSV file format. Then followthe steps.
# 1. Step 1 : Right click on table
# 2. Step 2 : Select "Table Data Import Wizard"
# 3. Step 3 : Select the file which we have to load (in our case, it is SuperStore_USA.csv) and press next.
# 4. Step 4 : Select create new table and give the table name and press next.
# 5. Step 5 : Select the required conditions and press next. The data is loaded Successfully

# %%
#3. Find out how much returns we have recieved and with a product id 
xls = pd.ExcelFile('E://pycharm.py//Datasets/SuperStore_USA.xlsx')
returns = pd.read_excel(xls, 'Returns',names = ["OrderID","Status"])
users = pd.read_excel(xls, 'Users')

# %%
orders_returns = pd.merge(orders, returns)
orders_returns.columns
# Out:
# Index(['RowID', 'OrderPriority', 'Discount', 'UnitPrice', 'ShippingCost',
#        'CustomerID', 'CustomerName', 'ShipMode', 'CustomerSegment',
#        'ProductCategory', 'ProductSub-Category', 'ProductContainer',
#        'ProductName', 'ProductBase Margin', 'Region', 'StateorProvince',
#        'City', 'PostalCode', 'OrderDate', 'ShipDate', 'Profit',
#        'Quantityorderednew', 'Sales', 'OrderID', 'Status'],
#       dtype='object')

# %%
a = pd.DataFrame(orders_returns)
a.head()
# Out:
#    RowID OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 0   1359           Low      0.05       5.85          2.27          21
# 1   1950        Medium      0.01       4.91          0.50         117
# 2   1951        Medium      0.09       4.00          1.30         117
# 3   5055          High      0.02       3.28          5.00         117
# 4   5573           Low      0.02      11.97          5.81         272
#
#            CustomerName     ShipMode CustomerSegment  ProductCategory  ...  \
# 0  Tony Wilkins Winters  Regular Air  Small Business  Office Supplies  ...
# 1           Linda Weiss  Regular Air     Home Office  Office Supplies  ...
# 2           Linda Weiss  Express Air     Home Office  Office Supplies  ...
# 3           Linda Weiss  Regular Air     Home Office  Office Supplies  ...
# 4         Eleanor Swain  Regular Air  Small Business  Office Supplies  ...
#
#   StateorProvince           City PostalCode  OrderDate   ShipDate    Profit  \
# ...

# %%
a[(a['Status']=='Returned')]['OrderID'] #There are total 98 orders which were returned
#In the question, Product ID is mentioned which is not available, So I have given the order ID instead.
# Out:
# 0      9895
# 1     13959
# 2     13959
# 3     36038
# 4     39490
#       ...
# 93     7107
# 94     7107
# 95    42823
# 96    13638
# 97    47109
# Name: OrderID, Length: 98, dtype: int64

# %%
#4. try  to join order and return data both in sql and pandas 
pd.merge(orders, returns)

#Join in sql
#select * from returns_done INNER JOIN orders ON orders.OrderID=returns_done.orderID;
# Out:
#     RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 0    1359            Low      0.05       5.85          2.27          21
# 1    1950         Medium      0.01       4.91          0.50         117
# 2    1951         Medium      0.09       4.00          1.30         117
# 3    5055           High      0.02       3.28          5.00         117
# 4    5573            Low      0.02      11.97          5.81         272
# ..    ...            ...       ...        ...           ...         ...
# 93    986  Not Specified      0.06      37.94          5.08        3075
# 94    987  Not Specified      0.10      55.29          5.08        3075
# 95   6041         Medium      0.05       4.28          6.18        3075
# 96   1910           High      0.05      14.48          1.99        3079
# 97   6625           High      0.06     128.24         12.65        3251
#
#             CustomerName     ShipMode CustomerSegment  ProductCategory  ...  \
# ...

# %% [markdown]
# ```python
# #5. Try to find out how many unique customer that we have
# cursor = mydb.cursor()
# cursor.execute("select count(distinct CustomerID) from SuperStore.orders") #2703
# print(cursor.fetchall())
# cursor.close()
# ```

# %%
total = orders['CustomerID'].unique()
len(total)
# Out:
# 2703

# %%
#6. try to find out in how many regions we are selling a product and who is a manager for a respective region 
users
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
len(orders['Region'].unique()) 
#There are 4 regions in total and the respective managers for each region are listed in above table 'users'
# Out:
# 4

# %%
#7. find out how many different different shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
Shipment_mode = orders['ShipMode']

# %%
count = pd.Series(Shipment_mode).value_counts()
count
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: ShipMode, dtype: int64

# %%
s = pd.DataFrame(count)
s
# Out:
#                 ShipMode
# Regular Air         7036
# Delivery Truck      1283
# Express Air         1107

# %%
total_ship_mode = s.sum()
total_ship_mode
# Out:
# ShipMode    9426
# dtype: int64

# %%
# percentage usablity of all the shipment mode with respect to dataset 
((s[['ShipMode']])/total_ship_mode)*100
# Out:
#                  ShipMode
# Regular Air     74.644600
# Delivery Truck  13.611288
# Express Air     11.744112

# %%
#8. Create a new coulmn and try to find our a diffrence between order date and shipment date
orders["difference_date"] =  orders['ShipDate'] - orders['OrderDate']

# %%
orders
# Out:
#       RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 0     18606  Not Specified      0.01       2.88          0.50           2
# 1     20847           High      0.01       2.84          0.93           3
# 2     23086  Not Specified      0.03       6.68          6.15           3
# 3     23087  Not Specified      0.01       5.68          3.60           3
# 4     23088  Not Specified      0.00     205.99          2.50           3
# ...     ...            ...       ...        ...           ...         ...
# 9421  20275       Critical      0.06      35.89         14.72        3402
# 9422  20276       Critical      0.00       3.34          7.49        3402
# 9423  24491  Not Specified      0.08     550.98         45.70        3402
# 9424  25914           High      0.10     105.98         13.99        3403
# 9425  24492  Not Specified      0.09       7.78          2.50        3403
#
#          CustomerName        ShipMode CustomerSegment  ProductCategory  ...  \
# ...

# %%
# 9. Based on Question number 8, find out for which order id we have shipment duration more than 10 days 
difference = orders['difference_date']

orders[(orders['difference_date'].dt.components['days']>10)]
# Out:
#       RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 643   18246       Critical      0.05      11.09          5.25         250
# 1548  23091         Medium      0.04     100.98          7.18         595
# 1549  23092         Medium      0.09       6.48          7.49         595
# 1678  20703  Not Specified      0.07     130.98         30.00         637
# 1679  20704  Not Specified      0.09      55.98          4.86         637
# 1680  20705  Not Specified      0.08     115.99          4.23         637
# 1697   2703  Not Specified      0.07     130.98         30.00         640
# 1698   2704  Not Specified      0.09      55.98          4.86         640
# 1699   2705  Not Specified      0.08     115.99          4.23         640
# 2515  18060            Low      0.02       2.21          1.00         964
# 5548  21603  Not Specified      0.02       5.58          1.99        2048
# 5673  19005            Low      0.06      65.99          2.50        2088
# ...

# %%
orders[(orders['difference_date'].dt.components['days']>10)]['OrderID']
# Out:
# 643     87215
# 1548    86318
# 1549    86318
# 1678    87957
# 1679    87957
# 1680    87957
# 1697    19556
# 1698    19556
# 1699    19556
# 2515    86177
# 5548    88223
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: OrderID, dtype: int64

# %%
#10. Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
all_data = pd.concat([orders,returns])

# %%
all_data.columns
# Out:
# Index(['RowID', 'OrderPriority', 'Discount', 'UnitPrice', 'ShippingCost',
#        'CustomerID', 'CustomerName', 'ShipMode', 'CustomerSegment',
#        'ProductCategory', 'ProductSub-Category', 'ProductContainer',
#        'ProductName', 'ProductBase Margin', 'Region', 'StateorProvince',
#        'City', 'PostalCode', 'OrderDate', 'ShipDate', 'Profit',
#        'Quantityorderednew', 'Sales', 'OrderID', 'difference_date', 'Status'],
#       dtype='object')

# %%
all_data[(all_data['difference_date'].dt.components['days']>15)]
# Out:
#         RowID  OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 643   18246.0       Critical      0.05      11.09          5.25       250.0
# 1678  20703.0  Not Specified      0.07     130.98         30.00       637.0
# 1680  20705.0  Not Specified      0.08     115.99          4.23       637.0
# 1697   2703.0  Not Specified      0.07     130.98         30.00       640.0
# 1699   2705.0  Not Specified      0.08     115.99          4.23       640.0
# 2515  18060.0            Low      0.02       2.21          1.00       964.0
# 5673  19005.0            Low      0.06      65.99          2.50      2088.0
# 5859  24392.0            Low      0.05      29.89          1.99      2143.0
# 5881  21257.0            Low      0.05       7.99          5.03      2153.0
# 8607  26351.0         Medium      0.00       8.32          2.38      3119.0
# 8609  26350.0         Medium      0.07     180.98         55.24      3119.0
# ...

# %%
#11. Group by region and find out which region is most profitable 
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = True)
# Out:
#     Region  Profit
# 2    South    1954
# 3     West    2284
# 1     East    2289
# 0  Central    2899

# %%
orders.groupby(['Region'])['Profit'].aggregate('count').reset_index().sort_values("Profit",ascending = True).max() #West Region is most Profitable
# Out:
# Region    West
# Profit    2899
# dtype: object

# %%
orders['Discount'].unique()
# Out:
# array([0.01, 0.03, 0.  , 0.09, 0.08, 0.02, 0.07, 0.1 , 0.05, 0.06, 0.04,
#        0.11, 0.17, 0.16, 0.25, 0.21])

# %%
#12. Try to find out overall in which country we are giving more discount 
[orders[orders['Discount']>0.1]['Region']] 
#In central region, we are giving the most discounts.
# Out:
# [5990    Central
#  5991    Central
#  6000    Central
#  8649    Central
#  8661    Central
#  Name: Region, dtype: object]

# %%
#13. Give me a list of unique postal code 
orders['PostalCode'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
orders[orders["Profit"]>100].nunique()
# Out:
# RowID                  2635
# OrderPriority             5
# Discount                 12
# UnitPrice               522
# ShippingCost            403
# CustomerID             1579
# CustomerName           1579
# ShipMode                  3
# CustomerSegment           4
# ProductCategory           3
# ProductSub-Category      17
# ProductContainer          7
# ProductName             775
# ProductBase Margin       51
# Region                    4
# StateorProvince          49
# City                   1106
# PostalCode             1278
# OrderDate              1084
# ShipDate               1136
# Profit                 2584
# Quantityorderednew       99
# Sales                  2619
# OrderID                2318
# difference_date          15
# dtype: int64

# %%
#14 . which customer segement is more profitable find it out . 
orders.groupby(['CustomerSegment'])['Profit'].aggregate('count') 
#The corporate Customer segment is more profitable than others
# Out:
# CustomerSegment
# Consumer          1894
# Corporate         3375
# Home Office       2316
# Small Business    1841
# Name: Profit, dtype: int64

# %%
#15. try to find out the 10th most loss making product catagory . 
orders[orders['Profit']<0].reset_index().sort_values('Profit', ascending = True).head(10)
# Out:
#       index  RowID  OrderPriority  Discount  UnitPrice  ShippingCost  \
# 2291   4659  18306         Medium      0.08     175.99          4.99
# 2121   4338  20972            Low      0.01      24.95          2.99
# 3811   7800  23213            Low      0.09    6783.02         24.49
# 2381   4844  21284       Critical      0.04     880.98         44.55
# 2660   5402  24076         Medium      0.04    6783.02         24.49
# 2664   5409  22942           High      0.05    3502.14          8.73
# 3771   7725  21048  Not Specified      0.06    6783.02         24.49
# 1061   2191  21575  Not Specified      0.05    3499.99         24.49
# 1977   4068  21917           High      0.06    3502.14          8.73
# 2387   4857  24251           High      0.05    3502.14          8.73
#
#       CustomerID          CustomerName        ShipMode CustomerSegment  ...  \
# 2291        1738          Dean Solomon     Regular Air       Corporate  ...
# ...

# %%
(orders.sort_values('Profit', ascending = True)).reset_index().iloc[[9]]
# Out:
#    index  RowID OrderPriority  Discount  UnitPrice  ShippingCost  CustomerID  \
# 9   4857  24251          High      0.05    3502.14          8.73        1796
#
#      CustomerName        ShipMode CustomerSegment  ... StateorProvince  \
# 9  Carlos Johnson  Delivery Truck       Corporate  ...      California
#
#             City PostalCode  OrderDate   ShipDate     Profit  \
# 9  San Francisco      94110 2013-03-23 2013-03-24 -7961.4309
#
#   Quantityorderednew   Sales  OrderID difference_date
# 9                  1  3360.3    90778          1 days
#
# [1 rows x 26 columns]

# %%
#16. Try to find out 10 top  product with highest margins 
orders.sort_values(['ProductBase Margin'])['ProductName'].head(10)
# Out:
# 2431              GBC DocuBind 200 Manual Binding Machine
# 8248       Peel & Seel® Recycled Catalog Envelopes, Brown
# 1515       Peel & Seel® Recycled Catalog Envelopes, Brown
# 5050       Peel & Seel® Recycled Catalog Envelopes, Brown
# 413                                           Accessory31
# 5034                          Prang Dustless Chalk Sticks
# 8308         Staples Brown Kraft Recycled Clasp Envelopes
# 8311     Storex DuraTech Recycled Plastic Frosted Binders
# 8318                                          Accessory31
# 1553    Adams Telephone Message Book w/Frequently-Call...
# Name: ProductName, dtype: object
